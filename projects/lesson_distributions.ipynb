# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Binomial Distribution

# %%
b = np.random.binomial(n=1, p=0.5, size=100000) #n number of coin tosses, p: probability of the coin
b
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ## Poisson
# Number of times a rare event occurs (e.g. 2 penguins dating)

# %%
L = 40/11
p = np.random.poisson(lam=L, size=100000)
pd.DataFrame(p).hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)
